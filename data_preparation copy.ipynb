# %% [markdown]
# # Data Preparation

# %% [markdown]
# While the data scrapper gets the data related to the instagram users, we are using two datasets from Kaggle with small variations to recreate how the algorithm will work with real data.

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Upload companies dataset
df_co = pd.read_csv('df_co.csv')
df_co
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Upload companies dataset
# ----> 2 df_co = pd.read_csv('df_co.csv')
#       3 df_co
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_co.csv'

# %%
# Upload users (influencers) dataset
df_influ = pd.read_csv('influenceData.csv')
df_influ
# Out:
#       Unnamed: 0.1  Unnamed: 0        user_Name  followers  \
# 0                0           0          chiquis  5,721,916
# 1                1           1          chiquis  5,721,916
# 2                2           2          chiquis  5,721,916
# 3                3           3          chiquis  5,721,916
# 4                4           4          chiquis  5,721,916
# ...            ...         ...              ...        ...
# 6215           495         495  sagar_goswami89    883,409
# 6216           496         496  sagar_goswami89    883,409
# 6217           497         497  sagar_goswami89    883,409
# 6218           498         498  sagar_goswami89    883,409
# 6219           499         499  sagar_goswami89    883,409
#
#                                        user_Description  \
# 0     Chiquis\nCon Dios Todo! -BFF 4Life!\nSinger\nE...
# 1     Chiquis\nCon Dios Todo! -BFF 4Life!\nSinger\nE...
# 2     Chiquis\nCon Dios Todo! -BFF 4Life!\nSinger\nE...
# 3     Chiquis\nCon Dios Todo! -BFF 4Life!\nSinger\nE...
# 4     Chiquis\nCon Dios Todo! -BFF 4Life!\nSinger\nE...
# ...                                                 ...
# 6215  SAGAR FAM 💧\nPersonal blog\nContent Creator 💢\...
# 6216  SAGAR FAM 💧\nPersonal blog\nContent Creator 💢\...
# 6217  SAGAR FAM 💧\nPersonal blog\nContent Creator 💢\...
# 6218  SAGAR FAM 💧\nPersonal blog\nContent Creator 💢\...
# 6219  SAGAR FAM 💧\nPersonal blog\nContent Creator 💢\...
#
#                                       post_Url likes  \
# 0     https://www.instagram.com/p/CqHKmO-vNQu/   NaN
# 1     https://www.instagram.com/p/CqB1sDtN2gG/   NaN
# 2     https://www.instagram.com/p/CqBkI9MNZhR/   NaN
# 3     https://www.instagram.com/p/CqBSU7ev5bz/   NaN
# 4     https://www.instagram.com/p/CqBN0PYJpgE/   NaN
# ...                                        ...   ...
# 6215  https://www.instagram.com/p/CqI_ymIpPqm/   NaN
# 6216  https://www.instagram.com/p/CqImnRxpDeB/   NaN
# 6217  https://www.instagram.com/p/CqH8G-UJY1y/   NaN
# 6218  https://www.instagram.com/p/CqHh0w-po00/   NaN
# 6219  https://www.instagram.com/p/CqFRjB3JTd5/   NaN
#
#                                        post_Description post_Location
# 0     True story. 💜💫\n\n@beflawlessskin will make yo...           NaN
# 1     Taking notes on that “el que quiere puede” min...           NaN
# 2     GRACIAS MEXICO!!!!! ❤️‍🔥😭🙌🏻\n@monitorlatino_\n...           NaN
# 3     We don’t talk about this enough in the Latine ...           NaN
# 4     I’m so honored to be celebrating #WomensHistor...           NaN
# ...                                                 ...           ...
# 6215  I m suffering 🚬 #sagargoswami #reels #trend #l...           NaN
# 6216  Beta baap se aise baat nai karte 😅👍🏻 #sagargos...           NaN
# 6217  Khatam Hua Fiqar 💔🙂 #sagargoswami #reels #tren...           NaN
# 6218  Wo Pyar Hi Kaisa 🙂💔 #sagargoswami #reels #tren...           NaN
# 6219  Haste Haste 😅👋 #sagargoswami #reels #trend #ta...           NaN
#
# [6220 rows x 9 columns]

# %%
df_influ['post_Location'].unique()
# Out:
# array([nan, 'Siem Reap', 'Studio Rio Motret', 'بهشت زهرا',
#        'Miami, Florida', 'Hotel Makanda', 'Paris, France',
#        'Las Vegas, Nevada', 'Va Beach, Virginia',
#        'Clínica VR Dermatologia e Cirurgia Plástica', 'Istanbul, Turkey',
#        'Positano, Italia', 'Tashkent, Uzbekistan', 'suwon.rest',
#        'Lagos, Nigeria', 'Jangan Selalu Menilai Orang Itu Buruk...',
#        'Memang Pantas Ni Singkong Bersahabat Ma Kopi Akur Bener Di Mulut,,,,,,',
#        'Arshika Hotel Bali',
#        'Tertawa Bercanda Bersama Pocong Kuntilanak Dan Hantu Lain Ditempat Sunyi',
#        'Kenapa kita bisa sakit ?', 'Kalesma Mykonos', 'Lollapalooza',
#        'Medellín, Antioquia', 'Warner Bros. World Abu Dhabi',
#        'Forbes España', 'Miami Beach, Florida', 'James L Knight Center',
#        'New York, New York', 'Picnic Festival', 'Austin, Texas',
#        'Köln, Germany', 'Górnik Zabrze S.A.', 'Hockenheimring', 'Germany',
#        'South Africa', 'Salt Lake City, Utah, USA', 'Help Us Help Them',
#        'Los Angeles, California', 'The Oscars Red Carpet',
#        'African Outpost', 'Expedition Everest', 'Griffith Park',
#        'Masjid Agung Demak',
#        'BUPERTA (Bumi Perkemahàn dan Tàman Wisata) Cibubur',
#        'Anyer Beach - Wisata Pantai Anyer', 'Málaga, Spain',
#        'São Paulo, Brazil', 'Kyrgyzstan',
#        "MNAC Museu Nacional D'Art De Catalunya@ Barcelona",
#        'New year New me', 'Pier59 Studios', 'Edinburgh, United Kingdom',
#        'The Pyramids of Giza', 'Cairo, Egypt',
#        'Sylvan Lake (South Dakota)', 'Theodore Roosevelt National Park',
#        'National Mall and Memorial Parks',
#        'Redwood National and State Parks (NPS)',
#        'Chaco Culture National Historical Park',
#        'Craters of the Moon National Monument & Preserve',
#        'Glacier National Park', 'Teatro Ventidio Basso di Ascoli Piceno',
#        'RSIA Bunda Jakarta', 'Olympia de Montréal', 'Alamodome',
#        'Rodeo Drive', 'St. Moritz Switzerland', 'Soho, Manhattan',
#        'Callejón del Beso', 'La Macha Rio', 'Goiania, Goiás, Brasil',
#        'Amazonas, Brasil', 'Praia dos Anjos - Arraial do Cabo, RJ',
#        'Goiânia, Brazil', 'Rio De Janeiro, Brazil',
#        'Sofitel Legend Casco Viejo, Panama City', 'Milan, Italy',
#        'Food52', 'Delhi, India', 'Mumbai, Maharashtra',
#        'Haridwar, Uttrakhand', 'California', 'Baki Konqres Merkezi',
#        'Theater Nieuwe Luxor Rotterdam', 'Small Place Coffee & Fun',
#        'Country Club El Bosque - Sur', 'PDC | Pacific Design Center',
#        'Ayada Maldives', 'C.C.C.T, Caracas', 'Caracas, Venezuela',
#        'Emirates Stadium', 'Newcastle, United Kingdom', 'Nef Stadyumu',
#        'Parc Des Princes', 'Stamford Bridge',
#        'City Ground, Nottingham Forest', 'Old Trafford',
#        'José Alvalade Stadium', 'Museo Guggenheim Bilbao',
#        'Peggy Guggenheim Collection', 'Hermoso EcoLodge',
#        'Ciudad Autónoma de Buenos Aires', 'Multitabaris Comafi',
#        'Puerto Rico', 'เกาะเฮ Hey Island At Phuket', 'Bursa,Turkey',
#        'Goiânia, Goiás, Brasil', 'Marlins Park', 'Hawaii', 'Moorea',
#        'Colorado, USA', 'Ohio , U.S.A', 'Mumbai - मुंबई', 'Mira Road',
#        'JBR Beach , Dubai', 'Dubai, United Arab Emirates',
#        'Al Seef Village Dubai Creek',
#        'The Late Late Show with James Corden', 'Youth & Beauty Clinic',
#        'La Bombonera, Buenos Aires, Argentina',
#        'Predio Entrenamiento Boca Juniors , Ezeiza', 'Hyderabad',
#        'London, United Kingdom', 'Batam, Riau, Indonesia',
#        'Sochi, Russia', 'Adler Beach', 'Adler Microdistrict',
#        'Адлер, Сочи', 'Hong Kong', 'Vila Olímpica Clara Nunes',
#        'Rio de Janeiro, Rio de Janeiro', 'Semarang Zoo',
#        'Rogers Park, Chicago', 'Badlands National Park, SD',
#        'Chicago Executive Airport', 'Les Trois Chevaux',
#        'Animal Kingdom Disney', 'Magic Kingdom At Walt Disney World',
#        'Universal Studios, Orlando . Florida', 'Salt Lake City, Utah',
#        'Nashville, Tennessee', 'Puerto Vallarta, Jalisco',
#        'Skybar at Mondrian', 'Cozumel Mexico',
#        'Gedung GRADHIKA Kompleks Gubernuran Jawa Tengah', 'Telemundo',
#        'Renaissance Aix-en-Provence Hotel', "L' Amour parfait",
#        'Gaia Monte Carlo', 'Israel', 'Tokyo，Japan', 'United Kingdom',
#        'India', 'The Mafia', 'Doha', 'Mexico City, Mexico', 'CDMX',
#        'Accra, Ghana', 'Brooklyn, New York', 'Boti falls',
#        'Londrina Parana Brasil', 'Universal Studios, Japan',
#        'Tokyo DisneySea', 'Ginza Tokyo', 'The Apurva Kempinski Bali',
#        'Czech Republic', 'Madrid, Spain', 'Rome, Italy',
#        'San Siro Stadium', 'Medellín, Colombia',
#        'Aeropuerto Internacional Arturo Merino Benítez',
#        'Scottsdale, Arizona', 'Lake Powell, Utah', 'Denver, Colorado',
#        'Cairo Airport', 'Egypt,Ismailia',
#        'Four Seasons Resort Dubai at Jumeirah Beach',
#        'Russia, Saint-Petersburg', 'Park Hyatt Dubai', 'Dubai UAE',
#        'Al Aziziyah Boutique Hotel', 'Jardim Acapulco - Guarujá',
#        'Rec. dos Passaros - Igarata', 'Phoenix, Arizona',
#        'Miami, Floride (U.S.A)', 'The Ananta Udaipur', 'ITC Royal Bengal',
#        'Bergamo, Italy', 'C.A.B.A', 'Cilacap Regency',
#        'Cidade Deportiva Afouteza', 'Beverly Hills, California',
#        'Faena Miami Beach', 'Amazonia', 'Loomen',
#        'Hotel Cristallo - Alta Badia - Dolomiti', 'Till Death Do Us Part',
#        'Garden Of The Gods', 'Roma', 'Barcelona, Spain', 'Barceloneta',
#        'Turkey, Istanbul', 'The Grill House Sentul City', '𝐠𝐢𝐬𝐞𝐥𝐥𝐞 𝐦𝐢𝐚𝐦𝐢',
#        'Sexy Fish Miami', 'St. Moritz', 'Courchevel 1850',
#        'الكويت - Kuwait', 'Qatar - Doha', 'Tripoli,libya',
#        'Dakhla - Morocco', 'Makkah Masjid-al-Haram', 'Lebanon لبنان',
#        'Dubai - دبى', 'Chichen itza "templo de kukulkan"', 'Freefire',
#        'Xenses Park', 'The Ritz-Carlton Jakarta, Pacific Place',
#        'Plaza Senayan XXI', 'Park Hyatt Jakarta', 'Pim3', 'Santa Salete',
#        'Teresina', 'Galeria Café', 'BQ Shopping', 'Catalão',
#        'Paragominas/ Pará - Brasil', 'Bogotá D.C, Colombia',
#        'The Late Show with Stephen Colbert', 'ModernHaus SoHo',
#        'Waldorf Astoria Maldives Ithaafushi', 'Wembley', 'Giraffe Manor',
#        'Cappadocia / Kapadokya', 'Bavaro, Punta Cana, Dominican Republic',
#        'Guatemala', 'Punta Blanca, Ruta Del Sol',
#        'Bernabeu Stadium, Madrid, Spain', 'Estadio Benito Villamarín',
#        'Anfield Stadium Liverpool Football Club', 'Soho House Mumbai',
#        'São Caetano do Sul', 'Abu Dhabi Grand Mosque',
#        'Boston Symphony Hall', 'Europe', 'Ireland', 'The Birthday One',
#        'Lincoln Center Theater', 'Campo Bahia Hotel Villas Spa',
#        'Four Seasons-Punta Mita', 'Dar es Salaam, Tanzania',
#        'Hamad International Airport', 'المسجد الحرام Masjid Al Haram',
#        'Medina, Saudi Arabia', 'Mystic Falls, Virginia',
#        'Washington D. C.', 'AlUla, Saudi Arabia', 'Texana',
#        'MIAMI florida / EE.UU', 'Ohio, USA', "Filo D'olio",
#        'Canary Wharf', 'Lollapalooza Brasil', 'Madurai - நம்ம மதுரை',
#        'Bali, Indonesia', 'Tokyo, Japan',
#        'Shinjuku Gyoen National Garden', 'Viareggio', 'Sanremo, Italy',
#        'Maldives', 'Indore, India', 'Indore City', 'Echostage',
#        'Raleigh, North Carolina', 'Charlotte, North Carolina',
#        'Myrtle Beach, South Carolina', 'The Grove', 'Brighton and Hove',
#        'Amex Stadium', 'Riverside Stadium', 'Goodison Park',
#        'Around The World', 'New York City', 'South Beach, Miami',
#        'Florida', 'Miami - Brickell', 'Guadalajara',
#        'Roosevelt Roads Naval Station', 'Rogelios Ice Plant', 'Ukraine',
#        'Seville, Spain', 'Ramón Sánchez Pizjuán Stadium',
#        'FIFA World Cup 2026', 'United States of America', 'Dallas, Texas',
#        'Boston, Massachusetts', 'Santa Monica Pier', 'Venice Beach',
#        'City Of Angels', 'Western Michigan University',
#        'Chandigarh, India', 'Goa Colva Beach', 'Telemundo Center',
#        'Riyadh, Saudi Arabia', 'Celtic Park', 'Hampden Park',
#        'Dundee United Football Club', 'Chateau Royal', 'Berlin, Germany',
#        'Berlinale - Berlin International Film Festival',
#        'National Theatre', 'Tate Modern, London', 'Devbag Beach',
#        'Abu Dhabi Cricket Stadium', 'Kilyos, Istanbul, Turkey',
#        'Prague, Czech Republic', 'Aqaba Jordan Middle-East',
#        'Wadi Arabeh وادي عربة', 'Petra-البتراء', 'Guadalajara, Jalisco',
#        'Canelas, Durango', 'Foro Sol', 'Campestre La Herradura',
#        'Rancho De Carboneras.', 'Palmarito Tochapán, Puebla, Mexico',
#        'Univision', 'Human Rights First', 'Johannesburg, South Africa',
#        'Terra Di Mezzo', 'Toscana, Italy',
#        'Palazzo Vecchio, Piazza della Signoria, Firenze',
#        'Palm Island, Grenadines', 'Monte Tamaro',
#        'Santa Cruz, California', 'Queenstown, New Zealand', 'Colombia',
#        'Bogotá, Colombia', 'Bucaramanga, Santander',
#        'Roma, Italia / Rome, Italy', 'Galleria Vittorio Emanuele II',
#        'Milano City', 'Galeries Lafayette', 'La Plagne',
#        '20ème arrondissement, Paris', 'République', 'YouTube',
#        'Four Seasons Hotel Bangkok', 'Gaysorn Village', 'ศาลหลักมือง',
#        'The Touch Clinic Siam Square',
#        'ศูนย์ศึกษาธรรมชาติและสัตว์ป่าเขาน้ำพุ', 'ปันหวาน แคมป์กราวด์',
#        'P&N Valley Camp', 'Restaurant Dachgarten',
#        'Hanseatisches Oberlandesgericht', 'Deutschland / Germany',
#        'Tirol Österreich', 'Deutschland', 'Stuttgart, Germany', 'Ischgl',
#        'Philadelphia, Pennsylvania', 'Sydney, Australia', 'Seoul, Korea',
#        'Kia Forum', '𝓗𝓮𝓪𝓿𝓮𝓷.', 'Almaty, Kazakhstan',
#        'Dubai Desert Safari', 'Hard Rock Live Hollywood',
#        'Manhattan, New York', 'Superstition',
#        'Disney California Adventure Park',
#        'Disneyland/Califonia Adventure', 'Disneyland', 'Reading Festival',
#        'Amsterdam, Netherlands', 'Ocean Isle Beach, North Carolina',
#        'Dewberry Farm', 'Ocean Isle Beach', 'Harrison, New York',
#        'Fort Lauderdale, Florida', 'Purchase, New York',
#        'Bronxville, New York', 'Tarzana, Los Angeles',
#        'Malibu, California', 'Mamaroneck, New York', 'Sapporo, Hokkaido',
#        'Sapporo Tanuki Koji Shopping Arcade',
#        'Niseko Grand Hirafu Ski Resort', 'Uni Murakami', 'Disney World',
#        'True Tramm Trunk', 'Rashtrapati Bhavan',
#        'Golden Temple, Amritsar, India', 'Iceland', 'Frankfurt, Germany',
#        'Loisaba Conservancy', 'House of Waine',
#        'Courchevel, Rhone-Alpes, France', 'Giza', 'Manila',
#        'Tower Bridge', 'Niku X', 'Lake Como, Italy', 'Lake Iseo - Italy',
#        'Varenna, Lake Como, Italy', 'Napoli', '❤Fiordo Di Furore❤',
#        'Tuscany, Italy', 'Italy', 'Umbria', 'Capri, Italy',
#        'Dreams Natura Resort & Spa', 'Hollywood, California',
#        'Palandöken Mountain', 'Türkiye', 'The Sound',
#        'Via Verde Country Club', 'Hunian Para Manusia Setengah Dewa',
#        'Indonesia Tercinta', 'Chicago, Illinois',
#        'Instituto Rogério Penna', 'Villa do Comendador',
#        'Clínica Gianoto', 'Boituva, São Paulo', 'Berlin', 'Ibiza',
#        'Paris', 'Ibiza Airport', 'Saint Benoit', 'Hendek',
#        'Tekirdağ Şarköy', 'Yeditepe Üniversitesi',
#        'İstanbul Kültür Üniversitesi', 'JW Marriott Hotel Kuala Lumpur',
#        'Toronto Ontario Canada', 'Snob Club Tanger',
#        'Backstage at the Grand Ole Opry', 'Grand Ole Opry',
#        'Nairobi, Kenya', 'Sri Lanka', 'Nine Arches Bridge, Demodara',
#        'আলিপুরদুয়ার', 'সুবর্ণচর উপজেলা, নোয়াখালী', 'Jaisalmer',
#        'Pune, Maharashtra', 'Jaipur, Rajasthan', 'Camp Nou Barcelona',
#        'San Diego, California'], dtype=object)

# %%
import requests

# Replace YOUR_API_KEY with your actual Google Maps API key
API_KEY = 'AIzaSyD4fTgqM_Ywm48NrDeJlk_itXfxE37aOUM'

def location (location_name):
    # Construct the URL for the geocoding API request
    url = f'https://maps.googleapis.com/maps/api/geocode/json?address={location_name}&key={API_KEY}'

    # Send the API request and get the response
    response = requests.get(url)

    # Parse the JSON response
    json_data = response.json()

    # Check if the results list is empty
    if not json_data['results']:
        return None
    else:
        # Extract the latitude and longitude of the location
        lat = json_data['results'][0]['geometry']['location']['lat']
        lng = json_data['results'][0]['geometry']['location']['lng']

        # Construct the URL for the reverse geocoding API request
        url = f'https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},{lng}&key={API_KEY}'

        # Send the API request and get the response
        response = requests.get(url)

        # Parse the JSON response
        json_data = response.json()

        # Extract the country name from the reverse geocoding result
        for result in json_data['results']:
            for component in result['address_components']:
                if 'country' in component['types']:
                    country_name = component['long_name']
                    break

        # return the country
        return country_name

# %%
loc = []

for i in range(len(df_influ['post_Location'])):
    loc.append(location(df_influ['post_Location'][i]))

df_influ['location'] = loc
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\socket.py:918, in getaddrinfo(host, port, family, type, proto, flags)
#     917 addrlist = []
# --> 918 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000022046A92D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=nan&key=AIzaSyD4fTgqM_Ywm48NrDeJlk_itXfxE37aOUM (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022046A92D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[11], line 4
#       1 loc = []
#       3 for i in range(len(df_influ['post_Location'])):
# ----> 4     loc.append(location(df_influ['post_Location'][i]))
#       6 df_influ['location'] = loc
#
# Cell In[9], line 11, in location(location_name)
#       8 url = f'https://maps.googleapis.com/maps/api/geocode/json?address={location_name}&key={API_KEY}'
#      10 # Send the API request and get the response
# ---> 11 response = requests.get(url)
#      13 # Parse the JSON response
#      14 json_data = response.json()
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\manue\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     if isinstance(e.reason, _SSLError):
#     562         # This branch is for urllib3 v1.22 and later.
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#     568     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=nan&key=AIzaSyD4fTgqM_Ywm48NrDeJlk_itXfxE37aOUM (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022046A92D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
import re

def get_hashtags(text):
    hashtags = re.findall(r'#\w+', text)
    return hashtags

# %%
has = []

for i in range(len(df_influ['post_Description'])):
    print(df_influ['post_Description'][i])
    has.append(get_hashtags(df_influ['post_Description'][i]))

df_influ['hashtags'] = has
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       1 has = []
#       3 for i in range(len(df_influ['post_Description'])):
# ----> 4     print(df_influ['post_Description'][i].tostring())
#       5     has.append(get_hashtags(df_influ['post_Description'][i]))
#       7 df_influ['hashtags'] = has
#
# AttributeError: 'str' object has no attribute 'tostring'

# %%
df_influ.isna().sum()
# Out:
# Unnamed: 0.1           0
# Unnamed: 0             0
# user_Name            190
# followers            200
# user_Description     210
# post_Url             160
# likes               3059
# post_Description     349
# post_Location       5215
# dtype: int64

# %% [markdown]
# We will now merge both dataframes, so that we can have interactions between both the companies and the users.

# %%
df2_co = pd.concat([df_co]*1000, ignore_index=True)

# %%
df2_influ = pd.DataFrame(np.repeat(df_influ.values, 100, axis=0), columns=["AccountID", "Account", "Link", "Followers", "Audience Country", "Authentic engagement", "Engagement avg", "Category1", "Hashtags", "Cost Story", "Cost Post"])

# %%
# Concat both df
df = pd.concat([df2_influ, df2_co], axis=1)

# %% [markdown]
# Now, we will transform the variable hashtags as an intenger, remove the # symbol and return a list of words.

# %%
def Convert(string):
    li = list(string.split("#"))
    return li

# %%
df['Hashtags'] = df['Hashtags'].astype(str)

# %%
h = []
h_co = []

for i in range(len(df['Hashtags'])):
    h.append(Convert(df['Hashtags'][i]))
    h_co.append(Convert(df['Hashtags_co'][i]))

df['Hashtags'] = h
df['Hashtags_co'] = h_co

# %%
# Remove first empty element
for i in range(len(df['Hashtags'])):
    df['Hashtags'][i].pop(0)
    df['Hashtags_co'][i].pop(0)

# %%
df
# Out:
#       AccountID    Account                                  Link    Followers  \
# 0             1  cristiano  https://www.instagram.com/cristiano/  400100000.0
# 1             1  cristiano  https://www.instagram.com/cristiano/  400100000.0
# 2             1  cristiano  https://www.instagram.com/cristiano/  400100000.0
# 3             1  cristiano  https://www.instagram.com/cristiano/  400100000.0
# 4             1  cristiano  https://www.instagram.com/cristiano/  400100000.0
# ...         ...        ...                                   ...          ...
# 99995      1000   eduincaz   https://www.instagram.com/eduincaz/    6200000.0
# 99996      1000   eduincaz   https://www.instagram.com/eduincaz/    6200000.0
# 99997      1000   eduincaz   https://www.instagram.com/eduincaz/    6200000.0
# 99998      1000   eduincaz   https://www.instagram.com/eduincaz/    6200000.0
# 99999      1000   eduincaz   https://www.instagram.com/eduincaz/    6200000.0
#
#       Audience Country Authentic engagement Engagement avg  \
# 0                India            7800000.0      9500000.0
# 1                India            7800000.0      9500000.0
# 2                India            7800000.0      9500000.0
# 3                India            7800000.0      9500000.0
# 4                India            7800000.0      9500000.0
# ...                ...                  ...            ...
# 99995           Mexico             305600.0       391900.0
# 99996           Mexico             305600.0       391900.0
# 99997           Mexico             305600.0       391900.0
# 99998           Mexico             305600.0       391900.0
# 99999           Mexico             305600.0       391900.0
#
#                 Category1                                           Hashtags  \
# 0      Sports with a ball  [football, entrepreneur, foodstylist, love, tr...
# 1      Sports with a ball  [football, entrepreneur, foodstylist, love, tr...
# 2      Sports with a ball  [football, entrepreneur, foodstylist, love, tr...
# 3      Sports with a ball  [football, entrepreneur, foodstylist, love, tr...
# 4      Sports with a ball  [football, entrepreneur, foodstylist, love, tr...
# ...                   ...                                                ...
# 99995           Lifestyle                                            [photo]
# 99996           Lifestyle                                            [photo]
# 99997           Lifestyle                                            [photo]
# 99998           Lifestyle                                            [photo]
# 99999           Lifestyle                                            [photo]
#
#       Cost Story  Cost Post  CompanyID              Name_co  \
# 0       468000.0  1092000.0          0      The Little Shop
# 1       468000.0  1092000.0          1     The Cozy Kitchen
# 2       468000.0  1092000.0          2            The Roost
# 3       468000.0  1092000.0          3     The Wooden Spoon
# 4       468000.0  1092000.0          4     Sunflower Fields
# ...          ...        ...        ...                  ...
# 99995    18336.0    42784.0         95        Copper Kettle
# 99996    18336.0    42784.0         96  The Crusty Baguette
# 99997    18336.0    42784.0         97       The Plaid Pail
# 99998    18336.0    42784.0         98      The Sugar House
# 99999    18336.0    42784.0         99          Urban Bites
#
#               Category_co                                        Hashtags_co  \
# 0                    Cars        [instadaily, food, followback, instatravel]
# 1      Sports with a ball  [instalike, fashion, holidayseason, skiing, lo...
# 2                     Art  [blessings, foodlife, endurance, fitnessmotiva...
# 3               Computers                          [foodislifee, familytime]
# 4              Management                                   [health, trendy]
# ...                   ...                                                ...
# 99995           Undefined                [baseball, friendshipgoals, skiing]
# 99996                Food      [instamood, education, beautifuldestinations]
# 99997              Luxury  [goodmorning, cricket, transportation, media, ...
# 99998            Business       [muscle, lifestyle, instatravel, instadaily]
# 99999               Shows                              [cricket, lifeisgood]
#
#       Country_co  Followers_co
# 0         Brazil        195608
# 1          Egypt        415795
# 2         Turkey        116164
# 3           Iran        524384
# 4        Germany        307127
# ...          ...           ...
# 99995   Thailand        354362
# 99996      China         74286
# 99997    Nigeria        108265
# 99998    Germany         82077
# 99999   Tanzania        445319
#
# [100000 rows x 17 columns]

# %% [markdown]
# Calculate the different number of points (score) for each pair of user-company depending on the match of different variables.

# %%
num_coincidente = df.apply(lambda row: len(set(row['Hashtags']).intersection(set(row['Hashtags_co']))), axis=1)
points_cat = np.where((df['Category1'] == df['Category_co']), 10, 0)
points_country = np.where((df['Audience Country'] == df['Country_co']), 5, 0)
points_eng = df['Authentic engagement']/df['Followers']
df['num_coincidentes'] = num_coincidente
df['points_eng'] = points_eng
df['points_cat'] = points_cat
df['points_country'] = points_country
df['Puntos'] = df['points_cat'] + df['points_country'] + df["num_coincidentes"] + df['points_eng']

df = df.drop(['points_cat', 'points_country', 'num_coincidentes', 'Engagement avg', 'points_eng'], axis=1)

# %% [markdown]
# Check and change variables types.

# %%
df.dtypes
# Out:
# AccountID               object
# Account                 object
# Link                    object
# Followers               object
# Audience Country        object
# Authentic engagement    object
# Category1               object
# Hashtags                object
# Cost Story              object
# Cost Post               object
# CompanyID                int64
# Name_co                 object
# Category_co             object
# Hashtags_co             object
# Country_co              object
# Followers_co             int64
# Puntos                  object
# dtype: object

# %%
df['Followers'] = df['Followers'].astype(int)
df['Authentic engagement'] = df['Authentic engagement'].astype(float)
df['Cost Story'] = df['Cost Story'].astype(float)
df['Followers_co'] = df['Followers_co'].astype(int)
df['Puntos'] = df['Puntos'].astype(float)
df.dtypes
# Out:
# AccountID                object
# Account                  object
# Link                     object
# Followers                 int32
# Audience Country         object
# Authentic engagement    float64
# Category1                object
# Hashtags                 object
# Cost Story              float64
# Cost Post                object
# CompanyID                 int64
# Name_co                  object
# Category_co              object
# Hashtags_co              object
# Country_co               object
# Followers_co              int32
# Puntos                  float64
# dtype: object

# %% [markdown]
# To fit the lightfm model, we will change the name of some columns to fit the model.

# %%
# Change the name of columns to fit the model.
df = df.rename(columns={"AccountID": "itemID", "CompanyID": "userID", "Puntos": "rating"})

# %% [markdown]
# Fill None values with 'Unknown'

# %%
df['Audience Country'] = df['Audience Country'].fillna('Unknown')

# %%
df
# Out:
#       itemID    Account                                  Link  Followers  \
# 0          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 1          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 2          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 3          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 4          1  cristiano  https://www.instagram.com/cristiano/  400100000
# ...      ...        ...                                   ...        ...
# 99995   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 99996   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 99997   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 99998   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 99999   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
#
#       Audience Country  Authentic engagement           Category1  \
# 0                India             7800000.0  Sports with a ball
# 1                India             7800000.0  Sports with a ball
# 2                India             7800000.0  Sports with a ball
# 3                India             7800000.0  Sports with a ball
# 4                India             7800000.0  Sports with a ball
# ...                ...                   ...                 ...
# 99995           Mexico              305600.0           Lifestyle
# 99996           Mexico              305600.0           Lifestyle
# 99997           Mexico              305600.0           Lifestyle
# 99998           Mexico              305600.0           Lifestyle
# 99999           Mexico              305600.0           Lifestyle
#
#                                                 Hashtags  Cost Story  \
# 0      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 1      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 2      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 3      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 4      [football, entrepreneur, foodstylist, love, tr...    468000.0
# ...                                                  ...         ...
# 99995                                            [photo]     18336.0
# 99996                                            [photo]     18336.0
# 99997                                            [photo]     18336.0
# 99998                                            [photo]     18336.0
# 99999                                            [photo]     18336.0
#
#        Cost Post  userID              Name_co         Category_co  \
# 0      1092000.0       0      The Little Shop                Cars
# 1      1092000.0       1     The Cozy Kitchen  Sports with a ball
# 2      1092000.0       2            The Roost                 Art
# 3      1092000.0       3     The Wooden Spoon           Computers
# 4      1092000.0       4     Sunflower Fields          Management
# ...          ...     ...                  ...                 ...
# 99995    42784.0      95        Copper Kettle           Undefined
# 99996    42784.0      96  The Crusty Baguette                Food
# 99997    42784.0      97       The Plaid Pail              Luxury
# 99998    42784.0      98      The Sugar House            Business
# 99999    42784.0      99          Urban Bites               Shows
#
#                                              Hashtags_co Country_co  \
# 0            [instadaily, food, followback, instatravel]     Brazil
# 1      [instalike, fashion, holidayseason, skiing, lo...      Egypt
# 2      [blessings, foodlife, endurance, fitnessmotiva...     Turkey
# 3                              [foodislifee, familytime]       Iran
# 4                                       [health, trendy]    Germany
# ...                                                  ...        ...
# 99995                [baseball, friendshipgoals, skiing]   Thailand
# 99996      [instamood, education, beautifuldestinations]      China
# 99997  [goodmorning, cricket, transportation, media, ...    Nigeria
# 99998       [muscle, lifestyle, instatravel, instadaily]    Germany
# 99999                              [cricket, lifeisgood]   Tanzania
#
#        Followers_co     rating
# 0            195608   0.019495
# 1            415795  10.019495
# 2            116164   0.019495
# 3            524384   0.019495
# 4            307127   0.019495
# ...             ...        ...
# 99995        354362   0.049290
# 99996         74286   0.049290
# 99997        108265   0.049290
# 99998         82077   0.049290
# 99999        445319   0.049290
#
# [100000 rows x 17 columns]

# %% [markdown]
# To recreate a realistic situation, where we won't have all users matched with all companies, we will remove some pairs and add new ones.

# %%
# Remove rows
remove_n = 3246
drop_indices = np.random.choice(df.index, remove_n, replace=False)
df = df.drop(drop_indices)

# %%
# Add rows
new_row = {'itemID':1001, 'Account':'jionast', 'Link':'https://www.instagram.com/jionast/', 'Followers':173571, 'Audience Country':'Spain', 'Authentic engagement':113456, 'Category1':'Lifestyle', 'Hashtags':['football', 'entrepreneur'], 'Cost Story':1111, 'Cost Post':1233, 'userID':100, 'Name_co':'Mcdonalds', 'Category_co':'Food', 'Hashtags_co':['football', 'food'], 'Country_co':'Spain', 'Followers_co':123445, 'rating':3}
df = df.append(new_row, ignore_index=True)
# Out:
# C:\Users\manue\AppData\Local\Temp\ipykernel_14992\1438693404.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)

# %% [markdown]
# The following dataframe will be the final dataset that will be used with the different algorithms.

# %%
df
# Out:
#       itemID    Account                                  Link  Followers  \
# 0          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 1          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 2          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 3          1  cristiano  https://www.instagram.com/cristiano/  400100000
# 4          1  cristiano  https://www.instagram.com/cristiano/  400100000
# ...      ...        ...                                   ...        ...
# 96750   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 96751   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 96752   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 96753   1000   eduincaz   https://www.instagram.com/eduincaz/    6200000
# 96754   1001    jionast    https://www.instagram.com/jionast/     173571
#
#       Audience Country  Authentic engagement           Category1  \
# 0                India             7800000.0  Sports with a ball
# 1                India             7800000.0  Sports with a ball
# 2                India             7800000.0  Sports with a ball
# 3                India             7800000.0  Sports with a ball
# 4                India             7800000.0  Sports with a ball
# ...                ...                   ...                 ...
# 96750           Mexico              305600.0           Lifestyle
# 96751           Mexico              305600.0           Lifestyle
# 96752           Mexico              305600.0           Lifestyle
# 96753           Mexico              305600.0           Lifestyle
# 96754            Spain              113456.0           Lifestyle
#
#                                                 Hashtags  Cost Story  \
# 0      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 1      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 2      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 3      [football, entrepreneur, foodstylist, love, tr...    468000.0
# 4      [football, entrepreneur, foodstylist, love, tr...    468000.0
# ...                                                  ...         ...
# 96750                                            [photo]     18336.0
# 96751                                            [photo]     18336.0
# 96752                                            [photo]     18336.0
# 96753                                            [photo]     18336.0
# 96754                           [football, entrepreneur]      1111.0
#
#        Cost Post  userID              Name_co         Category_co  \
# 0      1092000.0       0      The Little Shop                Cars
# 1      1092000.0       1     The Cozy Kitchen  Sports with a ball
# 2      1092000.0       2            The Roost                 Art
# 3      1092000.0       3     The Wooden Spoon           Computers
# 4      1092000.0       4     Sunflower Fields          Management
# ...          ...     ...                  ...                 ...
# 96750    42784.0      96  The Crusty Baguette                Food
# 96751    42784.0      97       The Plaid Pail              Luxury
# 96752    42784.0      98      The Sugar House            Business
# 96753    42784.0      99          Urban Bites               Shows
# 96754       1233     100            Mcdonalds                Food
#
#                                              Hashtags_co Country_co  \
# 0            [instadaily, food, followback, instatravel]     Brazil
# 1      [instalike, fashion, holidayseason, skiing, lo...      Egypt
# 2      [blessings, foodlife, endurance, fitnessmotiva...     Turkey
# 3                              [foodislifee, familytime]       Iran
# 4                                       [health, trendy]    Germany
# ...                                                  ...        ...
# 96750      [instamood, education, beautifuldestinations]      China
# 96751  [goodmorning, cricket, transportation, media, ...    Nigeria
# 96752       [muscle, lifestyle, instatravel, instadaily]    Germany
# 96753                              [cricket, lifeisgood]   Tanzania
# 96754                                   [football, food]      Spain
#
#        Followers_co     rating
# 0            195608   0.019495
# 1            415795  10.019495
# 2            116164   0.019495
# 3            524384   0.019495
# 4            307127   0.019495
# ...             ...        ...
# 96750         74286   0.049290
# 96751        108265   0.049290
# 96752         82077   0.049290
# 96753        445319   0.049290
# 96754        123445   3.000000
#
# [96755 rows x 17 columns]
